# %% [markdown]
# <a href="https://colab.research.google.com/github/KASHISHGOGIAA/ML-LAB/blob/main/ML_External_036_15_05_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#upload the file
from google.colab import files
uploaded = files.upload()
import pandas as pd
df = pd.read_csv('Advertising_2023.csv')
df.head()
# Out:
#      <input type="file" id="files-b1a83920-8984-4d89-83bc-6a31b5979467" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b1a83920-8984-4d89-83bc-6a31b5979467">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# No. of features
print("Total features in the dataset:", df.shape[1])
# Out:
# Total features in the dataset: 6

# %%
# Dimensions
print("Total rows and columns in the dataset:", df.shape)
# Out:
# Total rows and columns in the dataset: (1199, 6)

# %%
# Types of the features.
df.dtypes
# Out:
# Unnamed: 0      int64
# digital       float64
# TV            float64
# radio         float64
# newspaper     float64
# sales         float64
# dtype: object

# %%
# Finding null values.
print(df.isnull().sum())
# Out:
# Unnamed: 0    0
# digital       0
# TV            0
# radio         0
# newspaper     0
# sales         0
# dtype: int64

# %%
import statsmodels.api as sm
X = df[['TV', 'radio', 'newspaper']]
y = df['sales']
X = sm.add_constant(X)
model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  sales   R-squared:                       0.896
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     3440.
# Date:                Thu, 15 May 2025   Prob (F-statistic):               0.00
# Time:                        06:00:44   Log-Likelihood:                -2320.0
# No. Observations:                1199   AIC:                             4648.
# Df Residuals:                    1195   BIC:                             4668.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.9592      0.127     23.355      0.000       2.711       3.208
# ...

# %%
print("Training Accuracy:", model.rsquared)
# Out:
# Training Accuracy: 0.8962189708277737

# %%
from sklearn.metrics import mean_squared_error
y_pred = model.predict(X)
mse = mean_squared_error(y, y_pred)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 2.8069231413927067
